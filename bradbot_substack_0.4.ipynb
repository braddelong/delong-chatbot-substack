# %% [markdown]
# ## BradBot-SubStack 0.4

# %%
# !pip install gpt-index
# !pip install langchain
# !pip install PyPDF2
# Out:
# ...
# WARNING: There was an error checking the latest version of pip.
# ...
# WARNING: There was an error checking the latest version of pip.
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
from gpt_index import SimpleDirectoryReader, GPTListIndex
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/_y/07znhjvj71ncxr31txfsj07m0000gp/T/ipykernel_28702/461811237.py in <module>
# ----> 1 from gpt_index import SimpleDirectoryReader, GPTListIndex
#
# ~/github/gpt_index/gpt_index/__init__.py in <module>
#      13
#      14 # structured
# ---> 15 from gpt_index.indices.common.struct_store.base import SQLContextBuilder
#      16
#      17 # indices
#
# ~/github/gpt_index/gpt_index/indices/__init__.py in <module>
#       2
#       3 # indices
# ----> 4 from gpt_index.indices.keyword_table.base import GPTKeywordTableIndex
#       5 from gpt_index.indices.keyword_table.rake_base import GPTRAKEKeywordTableIndex
#       6 from gpt_index.indices.keyword_table.simple_base import GPTSimpleKeywordTableIndex
#
# ~/github/gpt_index/gpt_index/indices/keyword_table/__init__.py in <module>
#       2
#       3 # indices
# ...

# %%
from gpt_index import readers, GPTSimpleVectorIndex
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/_y/07znhjvj71ncxr31txfsj07m0000gp/T/ipykernel_28702/893524241.py in <module>
# ----> 1 from gpt_index import readers, GPTSimpleVectorIndex
#
# ~/github/gpt_index/gpt_index/__init__.py in <module>
#      13
#      14 # structured
# ---> 15 from gpt_index.indices.common.struct_store.base import SQLContextBuilder
#      16
#      17 # indices
#
# ~/github/gpt_index/gpt_index/indices/__init__.py in <module>
#       2
#       3 # indices
# ----> 4 from gpt_index.indices.keyword_table.base import GPTKeywordTableIndex
#       5 from gpt_index.indices.keyword_table.rake_base import GPTRAKEKeywordTableIndex
#       6 from gpt_index.indices.keyword_table.simple_base import GPTSimpleKeywordTableIndex
#
# ~/github/gpt_index/gpt_index/indices/keyword_table/__init__.py in <module>
#       2
#       3 # indices
# ...

# %%
from gpt_index import LLMPredictor, PromptHelper
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/_y/07znhjvj71ncxr31txfsj07m0000gp/T/ipykernel_28702/1349769982.py in <module>
# ----> 1 from gpt_index import LLMPredictor, PromptHelper
#
# ~/github/gpt_index/gpt_index/__init__.py in <module>
#      13
#      14 # structured
# ---> 15 from gpt_index.indices.common.struct_store.base import SQLContextBuilder
#      16
#      17 # indices
#
# ~/github/gpt_index/gpt_index/indices/__init__.py in <module>
#       2
#       3 # indices
# ----> 4 from gpt_index.indices.keyword_table.base import GPTKeywordTableIndex
#       5 from gpt_index.indices.keyword_table.rake_base import GPTRAKEKeywordTableIndex
#       6 from gpt_index.indices.keyword_table.simple_base import GPTSimpleKeywordTableIndex
#
# ~/github/gpt_index/gpt_index/indices/keyword_table/__init__.py in <module>
#       2
#       3 # indices
# ...
